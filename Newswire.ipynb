# %%
import numpy as np
import pandas as pd
from keras.datasets import reuters

# %%
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(
  num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2113536/2110848 [==============================] - 0s 0us/step
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/reuters.py:148: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/reuters.py:149: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
len(train_data)
# Out:
# 8982

# %%
len(test_data)
# Out:
# 2246

# %%
train_data[20]
# Out:
# [1,
#  779,
#  37,
#  38,
#  465,
#  278,
#  6623,
#  55,
#  900,
#  6,
#  2,
#  172,
#  4,
#  2,
#  2,
#  66,
#  474,
#  10,
#  920,
#  24,
#  41,
#  6432,
#  9691,
#  1333,
#  136,
#  4,
#  37,
#  38,
#  309,
#  2276,
#  198,
#  2020,
#  364,
#  2061,
#  6,
#  439,
#  2249,
#  1327,
#  5,
#  37,
#  38,
#  465,
#  247,
#  348,
#  4,
#  460,
#  356,
#  990,
#  1589,
#  8,
#  136,
#  1053,
#  3373,
#  634,
#  330,
#  116,
#  2061,
#  1185,
#  6,
#  2,
#  198,
#  236,
#  1176,
#  6,
#  3037,
#  6448,
#  1693,
#  238,
#  1720,
#  990,
#  309,
#  415,
#  265,
#  5992,
#  8945,
#  1149,
#  9118,
#  23,
#  779,
#  10,
#  103,
#  5,
#  465,
#  278,
#  6623,
#  7,
#  42,
#  1267,
#  6,
#  6432,
#  4,
#  3373,
#  7,
#  269,
#  10,
#  583,
#  43,
#  6,
#  2070,
#  1762,
#  6,
#  30,
#  3069,
#  13,
#  4,
#  1185,
#  199,
#  8,
#  4,
#  6623,
#  348,
#  990,
#  313,
#  415,
#  265,
#  6016,
#  5731,
#  1149,
#  7108,
#  9816,
#  2,
#  1149,
#  2,
#  1460,
#  2,
#  1149,
#  2,
#  1251,
#  2,
#  1149,
#  2,
#  9,
#  2,
#  2,
#  1324,
#  6131,
#  75,
#  91,
#  2,
#  172,
#  4,
#  66,
#  474,
#  10,
#  1220,
#  6,
#  6592,
#  1968,
#  398,
#  9,
#  2841,
#  22,
#  342,
#  203,
#  4,
#  1220,
#  6132,
#  27,
#  2953,
#  2412,
#  2,
#  1324,
#  2775,
#  41,
#  6717,
#  4,
#  5513,
#  5,
#  182,
#  7,
#  4441,
#  552,
#  58,
#  45,
#  203,
#  62,
#  3045,
#  8091,
#  6,
#  37,
#  38,
#  398,
#  2,
#  474,
#  7718,
#  22,
#  10,
#  105,
#  534,
#  27,
#  4,
#  141,
#  66,
#  259,
#  24,
#  203,
#  22,
#  392,
#  5,
#  2043,
#  2,
#  51,
#  45,
#  1744,
#  8976,
#  9,
#  2478,
#  1968,
#  62,
#  2,
#  37,
#  38,
#  398,
#  4,
#  8315,
#  8749,
#  57,
#  4095,
#  392,
#  40,
#  2169,
#  3769,
#  898,
#  5,
#  2043,
#  6022,
#  31,
#  1744,
#  1968,
#  17,
#  12]

# %%
train_labels[5]
# Out:
# 4

# %%
def vectorize_sequences(sequences, dimension=10000):
  results = np.zeros((len(sequences), dimension))
  for i, sequence in enumerate(sequences):
    results[i, sequence] = 1.
  return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
def to_one_hot(labels, dimension=46):
  results = np.zeros((len(labels), dimension))
  for i, label in enumerate(labels):
    results[i, label] = 1.
  return results

one_hot_train_labels = to_one_hot(train_labels)
one_hot_test_labels = to_one_hot(test_labels)

# %%
from keras.utils.np_utils import to_categorical

one_hot_train_labels = to_categorical(train_labels)
one_hot_test_labels = to_categorical(test_labels)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]

y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 2s 72ms/step - loss: 3.1652 - accuracy: 0.3987 - val_loss: 1.7675 - val_accuracy: 0.6540
# Epoch 2/20
# 16/16 [==============================] - 1s 48ms/step - loss: 1.5652 - accuracy: 0.6971 - val_loss: 1.3160 - val_accuracy: 0.7170
# Epoch 3/20
# 16/16 [==============================] - 1s 45ms/step - loss: 1.1233 - accuracy: 0.7601 - val_loss: 1.1444 - val_accuracy: 0.7390
# Epoch 4/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.8697 - accuracy: 0.8105 - val_loss: 1.0657 - val_accuracy: 0.7570
# Epoch 5/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.6765 - accuracy: 0.8533 - val_loss: 0.9930 - val_accuracy: 0.7830
# Epoch 6/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.5723 - accuracy: 0.8818 - val_loss: 0.9098 - val_accuracy: 0.8040
# Epoch 7/20
# 16/16 [==============================] - 1s 45ms/step - loss: 0.4456 - accuracy: 0.9095 - val_loss: 0.8992 - val_accuracy: 0.8060
# Epoch 8/20
# 16/16 [==============================] - 1s 48ms/step - loss: 0.3674 - accuracy: 0.9222 - val_loss: 0.8730 - val_accuracy: 0.8160
# Epoch 9/20
# 16/16 [==============================] - 1s 45ms/step - loss: 0.2696 - accuracy: 0.9438 - val_loss: 0.8624 - val_accuracy: 0.8230
# Epoch 10/20
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2470 - accuracy: 0.9468 - val_loss: 0.9817 - val_accuracy: 0.7900
# Epoch 11/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.2139 - accuracy: 0.9488 - val_loss: 0.8807 - val_accuracy: 0.8230
# Epoch 12/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1788 - accuracy: 0.9541 - val_loss: 0.9011 - val_accuracy: 0.8240
# Epoch 13/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1565 - accuracy: 0.9580 - val_loss: 0.8992 - val_accuracy: 0.8230
# Epoch 14/20
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1431 - accuracy: 0.9590 - val_loss: 0.9616 - val_accuracy: 0.8110
# Epoch 15/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1302 - accuracy: 0.9620 - val_loss: 0.9476 - val_accuracy: 0.8190
# Epoch 16/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1288 - accuracy: 0.9576 - val_loss: 0.9798 - val_accuracy: 0.8060
# Epoch 17/20
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1176 - accuracy: 0.9611 - val_loss: 1.0414 - val_accuracy: 0.7970
# Epoch 18/20
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1207 - accuracy: 0.9596 - val_loss: 1.0107 - val_accuracy: 0.8150
# Epoch 19/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1055 - accuracy: 0.9628 - val_loss: 1.0678 - val_accuracy: 0.8040
# Epoch 20/20
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1025 - accuracy: 0.9634 - val_loss: 1.0460 - val_accuracy: 0.7960

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(partial_x_train,
          partial_y_train,
          epochs=9,
          batch_size=512,
          validation_data=(x_val, y_val))
results = model.evaluate(x_test, one_hot_test_labels)
# Out:
# Epoch 1/9
# 16/16 [==============================] - 1s 57ms/step - loss: 3.1667 - accuracy: 0.4051 - val_loss: 1.8440 - val_accuracy: 0.6510
# Epoch 2/9
# 16/16 [==============================] - 1s 45ms/step - loss: 1.6071 - accuracy: 0.6886 - val_loss: 1.4126 - val_accuracy: 0.7080
# Epoch 3/9
# 16/16 [==============================] - 1s 47ms/step - loss: 1.1569 - accuracy: 0.7528 - val_loss: 1.1858 - val_accuracy: 0.7460
# Epoch 4/9
# 16/16 [==============================] - 1s 45ms/step - loss: 0.8910 - accuracy: 0.8111 - val_loss: 1.0634 - val_accuracy: 0.7740
# Epoch 5/9
# 16/16 [==============================] - 1s 45ms/step - loss: 0.7014 - accuracy: 0.8521 - val_loss: 0.9955 - val_accuracy: 0.7770
# Epoch 6/9
# 16/16 [==============================] - 1s 46ms/step - loss: 0.5677 - accuracy: 0.8851 - val_loss: 0.9586 - val_accuracy: 0.7960
# Epoch 7/9
# 16/16 [==============================] - 1s 45ms/step - loss: 0.4453 - accuracy: 0.9137 - val_loss: 0.9267 - val_accuracy: 0.8020
# Epoch 8/9
# 16/16 [==============================] - 1s 46ms/step - loss: 0.3744 - accuracy: 0.9265 - val_loss: 0.8867 - val_accuracy: 0.8150
# Epoch 9/9
# 16/16 [==============================] - 1s 44ms/step - loss: 0.3069 - accuracy: 0.9385 - val_loss: 0.9081 - val_accuracy: 0.8100
# 71/71 [==============================] - 0s 2ms/step - loss: 0.9987 - accuracy: 0.7778

# %%
results
# Out:
# [0.9986730813980103, 0.777827262878418]

# %%
import copy
test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
hits_array = np.array(test_labels) == np.array(test_labels_copy)
float(np.sum(hits_array)) / len(test_labels)
# Out:
# 0.17542297417631345

# %%
predictions = model.predict(x_test)

# %%
predictions[0].shape
# Out:
# (46,)

# %%
np.sum(predictions[0])
# Out:
# 1.0

# %%
 np.argmax(predictions[0])
# Out:
# 3
